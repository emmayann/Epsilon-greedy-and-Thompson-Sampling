# %%
from Bandit import ThompsonSampling,EpsilonGreedy

# %%
thompson = ThompsonSampling(5)
epsilon_greedy = EpsilonGreedy(5)

# %%
result_thompson = thompson.experiment(2000)
result_epsilon_greedy = epsilon_greedy.experiment(2000)

# %%
thompson.plot1(result_thompson)

# %%
epsilon_greedy.plot1(result_epsilon_greedy)
#the epsilon-greedy algorithm ends up using the rewards 2 bandit when decaying episoln with 1/t

# %%
thompson.report(result_thompson,result_epsilon_greedy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 thompson.report(result_thompson,result_epsilon_greedy)
#
# AttributeError: 'ThompsonSampling' object has no attribute 'report'
